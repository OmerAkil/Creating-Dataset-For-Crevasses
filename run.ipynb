# %%
# %run PreProcessing/MakeCompatibleImages.py
# Out:
# Found 2 .tif files in /home/omerakil/CrevasseCNN/Images
# tae6_r1.tif
# tae_8.tif
# Done. Compatible images written to: /home/omerakil/CrevasseCNN/InputImages

# %%
# %run run_single_test.py
# Out:
# DIPlib -- a quantitative image analysis library
# Version 3.3.0 (Nov  3 2025)
# For more information see https://diplib.org
# Running river detection on tae_8.tif (sensor=WV)
# process tae_8
# process tae_8_bandpass
# process tae_8_bandpass_gabor
# River detection finished.

# %%
# %run PostProcessing/BinarizeImages.py
# Out:
# Found 1 input files in /home/omerakil/CrevasseCNN/RiverOutput
# Processing: tae_8_crevasse_gray_bandpass_gabor_cpo20.tif
# Done. Binary images written to: /home/omerakil/CrevasseCNN/PostProcessing/BinaryOutput

# %%
# %run PostProcessing/MaskBorder.py
# Out:
# Processing: tae_8_crevasse_gray
#   Wrote: FracMap_tae_8_crevasse_gray.tif, DataMask_tae_8_crevasse_gray.tif

# %%
# %run PostProcessing/CreateImageChips.py
# Out:
# Using kernel size: 294 x 294 pixels
#
# Processing: tae_8_crevasse_gray
# tae_8_crevasse_gray: WV img min/max after scale = 0 / 255
#   Valid tiles: 336
# tae_8_crevasse_gray: wv_img global min/max = 0 / 255
#   Valid tiles after fracture filter: 328
#   Wrote NetCDF: /home/omerakil/CrevasseCNN/PostProcessing/Masked/tae_8_crevasse_gray.nc
#   Wrote CSV: /home/omerakil/CrevasseCNN/PostProcessing/Masked/FracTiles_tae_8_crevasse_gray.csv
#
# Total tiles across all images: 328
